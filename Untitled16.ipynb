# %%
# !pip install mpl-toolkits.clifford

# %%
# !pip install pylab-sdk
# Out:
# ...
#   Using cached pylab_sdk-1.3.2-py3-none-any.whl (3.9 kB)
# ...

# %%
# !pip install pyopenms

# %%
# !pip install matplotlib

# %%
# !pip install mplot3d-dragger

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
import matplotlib.cm as cm
x = np.random.randint(low=100, high=500, size=(50,))
y = np.random.randint(low=300, high=500, size=(50,))
z = np.random.randint(low=200, high=500, size=(50,))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

color_map = cm.ScalarMappable(cmap=cm.Reds_r)
clr = [x + y + z]
color_map.set_array(clr)

img = ax.scatter(x, y, z, s=200, color='red')
plt.colorbar(color_map)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
import matplotlib.cm as cm
exp=MSExperiment()
MzMLFile().load("C:/Users/TC/Downloads/ea10678.mzML",exp)
MZ_list=[]
init_list=[]
rt_list=[]
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(111, projection='3d')
color_map = cm.ScalarMappable(cmap=cm.Reds_r)
clr = [MZ_list + init_list + rt_list]
color_map.set_array(clr)
for i in range(10):
    spectrum=exp[i]
    
    if spectrum.getMSLevel()==1:
        MZ, Int= spectrum.get_peaks()
        MZ_list.extend(MZ)
        init_list.extend(Int)
        RT=[spectrum.getRT()]*len(MZ)
        rt_list.extend(RT)
        img = ax.scatter(MZ,Int, RT,s=200 ,color='red')
plt.colorbar(color_map)
ax.set_title("3D Heatmap")
ax.set_xlabel('M/Z')
ax.set_ylabel('Retention time')
ax.set_zlabel('Intensity')

plt.show()

# %%
import pandas as PD

E={"MZ":MZ_list,"Intensity":init_list,"RT":rt_list}
Ex=PD.DataFrame(data=E)
print(Ex)
# Out:
#                MZ     Intensity        RT
# 0      402.180206   6799.568359  0.086273
# 1      403.179443   4481.232422  0.086273
# 2      403.232849  34314.855469  0.086273
# 3      403.305481  15980.380859  0.086273
# 4      404.149323  25674.568359  0.086273
# ...           ...           ...       ...
# 2299  1589.330933   6112.163086  2.730853
# 2300  1590.216797   5206.527832  2.730853
# 2301  1591.270508   6666.625977  2.730853
# 2302  1592.721680   4613.670410  2.730853
# 2303  1594.655151   6506.841797  2.730853
#
# [2304 rows x 3 columns]

# %%
max(MZ_list)

indexOfMz=[]
for i in range(len(MZ_list)):
    if round(MZ_list[i]) ==round(1592) or round(MZ_list[i]) ==round(1591):
        indexOfMz.append(i)

# %%
indexOfMz
# Out:
# [465, 466, 1103, 2301]

# %%
init_list[indexOfMz[0]]
# Out:
# 8184.786

# %%
rt_list[indexOfMz[0]]
# Out:
# 0.08627281601999999

# %%
for i in range(len(indexOfMz)):
    x=rt_list[i]
    print(x)
# Out:
# 0.08627281601999999
# 0.08627281601999999
# 0.08627281601999999
# 0.08627281601999999

# %%
for i in range(len(indexOfMz)):
    x=init_list[i]
    print(x)
# Out:
# 6799.5684
# 4481.2324
# 34314.855
# 15980.381

# %%
import matplotlib.pyplot as plot
plot.plot(rt_list,init_list,color='blue')
plt.xlabel("Retenton time")
plt.ylabel("Intensity")
plt.title("For specific Mz")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
import matplotlib.cm as cm


fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

color_map = cm.ScalarMappable(cmap=cm.Reds_r)
clr = [rt_list+ init_list]
color_map.set_array(clr)

img = ax.scatter(rt_list, init_list, s=200, color='red')
plt.colorbar(color_map)

plt.show()
